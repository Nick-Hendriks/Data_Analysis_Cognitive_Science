# %% [markdown]
# Module 3
#
# from nltk.corpus import stopwords
# stop_words = stopwords.words('english') can be 'dutch'
# print(stop_words[:10])
#
# words = word_tokenize(text)
# filtered_sentence = [w for w in ]

# %%
import gensim
import nltk
