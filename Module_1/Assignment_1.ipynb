# %% [markdown]
# #Assignment 1.1

# %%
import numpy as np
import matplotlib.pyplot as plt

#example data
a = np.array([2025, 2030, 2035, 2040, 2045])
b = np.array([120, 80, 108, 99, 120])

fig, ax = plt.subplots(1)
ax.plot(a, b, color='lime')
ax.set_xlabel('year')
ax.set_ylabel('some value')
# Out:
# Text(0, 0.5, 'some value')
